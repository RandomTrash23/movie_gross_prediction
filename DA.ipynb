# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df=pd.read_csv(r'C:\Users\USER\Downloads\archive.zip')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df['genre'].value_counts()
# Out:
# genre
# Comedy       2245
# Action       1705
# Drama        1518
# Crime         551
# Biography     443
# Adventure     427
# Animation     338
# Horror        322
# Fantasy        44
# Mystery        20
# Thriller       16
# Family         11
# Sci-Fi         10
# Romance        10
# Western         3
# Musical         2
# Music           1
# History         1
# Sport           1
# Name: count, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# R            3697
# PG-13        2112
# PG           1252
# Not Rated     283
# G             153
# Unrated        52
# NC-17          23
# TV-MA           9
# TV-PG           5
# X               3
# Approved        1
# TV-14           1
# Name: count, dtype: int64

# %%
g_1=df['genre'].value_counts().head(8)
g_1=g_1.sort_values(ascending=True)
plt.barh(g_1.index,g_1.values)
plt.title('Movies per Genre')
plt.show()

# %%
g_2=df['rating'].value_counts().head(8)
g_2=g_2.sort_values(ascending=True)
plt.barh(g_2.index,g_2.values)
plt.title('Number of movies on basis of ratings')
plt.show()

# %%
df.dropna(subset=['budget'],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5497 entries, 0 to 7666
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5497 non-null   object
#  1   rating    5477 non-null   object
#  2   genre     5497 non-null   object
#  3   year      5497 non-null   int64
#  4   released  5497 non-null   object
#  5   score     5494 non-null   float64
#  6   votes     5494 non-null   float64
#  7   director  5497 non-null   object
#  8   writer    5497 non-null   object
#  9   star      5496 non-null   object
#  10  country   5496 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     5436 non-null   float64
#  13  company   5491 non-null   object
#  14  runtime   5495 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 687.1+ KB

# %%
df.dropna(subset=['gross'],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5436 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5436 non-null   object
#  1   rating    5424 non-null   object
#  2   genre     5436 non-null   object
#  3   year      5436 non-null   int64
#  4   released  5436 non-null   object
#  5   score     5436 non-null   float64
#  6   votes     5436 non-null   float64
#  7   director  5436 non-null   object
#  8   writer    5436 non-null   object
#  9   star      5436 non-null   object
#  10  country   5435 non-null   object
#  11  budget    5436 non-null   float64
#  12  gross     5436 non-null   float64
#  13  company   5434 non-null   object
#  14  runtime   5435 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 679.5+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5436.000000  5436.000000  5.436000e+03  5.436000e+03  5.436000e+03
# mean   2001.651582     6.392642  1.149110e+05  3.593864e+07  1.030045e+08
# std      10.541791     0.963200  1.842255e+05  4.154770e+07  1.871051e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.067412e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.100000e+07  3.671199e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.119478e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  5435.000000
# mean    108.156394
# std      18.121401
# min      63.000000
# 25%      95.000000
# 50%     105.000000
# 75%     118.000000
# max     271.000000

# %%
df.drop(labels='released',axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5436 entries, 0 to 7652
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5436 non-null   object
#  1   rating    5424 non-null   object
#  2   genre     5436 non-null   object
#  3   year      5436 non-null   int64
#  4   score     5436 non-null   float64
#  5   votes     5436 non-null   float64
#  6   director  5436 non-null   object
#  7   writer    5436 non-null   object
#  8   star      5436 non-null   object
#  9   country   5435 non-null   object
#  10  budget    5436 non-null   float64
#  11  gross     5436 non-null   float64
#  12  company   5434 non-null   object
#  13  runtime   5435 non-null   float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 637.0+ KB

# %%
min_gross=df['gross'].idxmin()
df.iloc[min_gross]
# Out:
# name               Man-Thing
# rating                     R
# genre                 Action
# year                    2005
# score                    4.0
# votes                 6100.0
# director       Brett Leonard
# writer          Steve Gerber
# star           Jack Thompson
# country        United States
# budget            30000000.0
# gross              1123136.0
# company     Lions Gate Films
# runtime                 97.0
# Name: 4780, dtype: object

# %%
df['profit_percent']=((df.gross-df.budget)/(df.budget))*100

# %%
df.groupby('genre')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='mean',ascending=False)
# Out:
#            count        min           max         mean      median
# genre
# Horror       254 -99.716250  1.288939e+06  7575.655318  204.721820
# Family         4 -88.842137  7.451529e+03  2013.018822  344.694169
# Thriller       7 -96.715543  1.210646e+03   329.977546  270.223850
# Animation    278 -99.620262  4.550609e+03   299.152876  192.961140
# Drama        869 -99.994992  1.385781e+04   271.810445   52.643691
# Comedy      1496 -99.997940  1.157085e+04   263.661820   78.755638
# Adventure    327 -99.575762  1.083670e+04   212.830031   87.796689
# Action      1417 -99.940600  2.905600e+04   193.486887   87.229047
# Mystery       17 -98.063116  9.059236e+02   180.462118   97.723275
# Biography    312 -99.415404  2.749162e+03   171.224635   47.640452
# Fantasy       42 -97.858800  8.954049e+02   151.599541  114.280660
# Crime        400 -99.816310  2.574110e+03   133.550143   31.468972
# Sci-Fi         6 -78.333333  4.994424e+02    99.537664  -28.013253
# ...

# %%
d1 = df.groupby('genre')['profit_percent'].agg(['count','median']).sort_values(by='count',ascending=False)
d1 = d1.reset_index()
df_melted = d1.melt(id_vars='genre', value_vars=['count', 'median'], var_name='Statistic', value_name='Value')
plt.figure(figsize=(12, 8))
sns.barplot(x='Value', y='genre', hue='Statistic', data=df_melted, palette='viridis')
plt.title('Count, and Median Profit Percentage by Genre')
plt.xlabel('Value')
plt.ylabel('Genre')
plt.legend(title='Statistic')
plt.show()

# %%
df.groupby('rating')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='mean',ascending=False)
# Out:
#            count         min           max        mean      median
# rating
# R           2597  -99.894004  1.288939e+06  934.732529   55.305553
# TV-MA          2  -98.487050  1.358318e+03  629.915342  629.915342
# Approved       1  462.542769  4.625428e+02  462.542769  462.542769
# G            111  -97.322896  4.550609e+03  318.449436  171.453183
# Unrated       17  -96.123545  2.941789e+03  283.011527   64.224622
# PG           909  -99.620262  1.143472e+04  245.770276  105.144871
# PG-13       1730  -99.997940  8.817581e+03  231.915246  107.926233
# Not Rated     44  -99.948920  4.938247e+03  210.200039  -30.581019
# NC-17         12  -87.238893  7.447514e+02  186.808674   82.452983
# X              1    1.096165  1.096165e+00    1.096165    1.096165

# %%
d2 = df.groupby('rating')['profit_percent'].agg(['count','median']).sort_values(by='count',ascending=False)
d2 = d2.reset_index()
df_melted_2 = d2.melt(id_vars='rating', value_vars=['count', 'median'], var_name='Statistic', value_name='Value')
plt.figure(figsize=(12, 8))
sns.barplot(x='Value', y='rating', hue='Statistic', data=df_melted_2, palette='viridis')
plt.title('Count, and Median Profit Percentage by rating')
plt.xlabel('Value')
plt.ylabel('rating')
plt.legend(title='Statistic')
plt.show()

# %%
df.groupby('genre')['score'].agg(['count','min','max','mean','median']).sort_values(by='mean',ascending=False)
# Out:
#            count  min  max      mean  median
# genre
# Biography    312  4.7  8.9  7.084936    7.10
# Drama        869  2.3  9.3  6.723590    6.80
# Animation    278  3.3  8.6  6.695683    6.70
# Crime        400  3.4  8.9  6.690250    6.65
# Family         4  5.9  7.8  6.675000    6.50
# Mystery       17  5.0  8.4  6.670588    6.70
# Romance        5  5.9  7.0  6.580000    7.00
# Sci-Fi         6  5.9  7.4  6.350000    6.20
# Adventure    327  2.4  8.6  6.268196    6.40
# Action      1417  2.1  9.0  6.247212    6.30
# Comedy      1496  1.9  8.6  6.190709    6.30
# Fantasy       42  4.2  7.6  6.004762    6.05
# Western        2  5.5  6.4  5.950000    5.95
# Thriller       7  4.7  6.6  5.928571    6.10
# Horror       254  3.2  8.1  5.825197    5.90

# %%
d3 = df.groupby('genre')['score'].agg(['median','mean']).sort_values(by='median',ascending=False)
d3 = d3.reset_index()
df_melted_3 = d3.melt(id_vars='genre', value_vars=['median','mean'], var_name='Statistic', value_name='Value')
plt.figure(figsize=(12, 8))
sns.barplot(x='Value', y='genre', hue='Statistic', data=df_melted_3, palette='viridis')
plt.title('median and mean score by genre')
plt.xlabel('Value')
plt.ylabel('Genre')
plt.legend(title='Statistic')
plt.show()

# %%
##directors who were the most active
df.groupby('director')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='count',ascending=False).head(20)
# Out:
#                    count        min          max        mean      median
# director
# Woody Allen           33 -95.135660   792.080882   81.284071  -16.067326
# Clint Eastwood        31 -90.336983  1005.260049  241.534462  142.630111
# Steven Spielberg      27 -36.460869  7451.529086  750.644852  323.528385
# Ron Howard            23 -55.946379   772.766675  241.139959  193.361679
# Steven Soderbergh     23 -95.768000  2296.285157  297.251229   71.940200
# Ridley Scott          23 -84.699151   483.483748  113.924695   67.786636
# Joel Schumacher       20 -98.512990   652.593369  125.642803  111.305079
# Martin Scorsese       19 -99.390658   420.834197   90.023011   87.853108
# Tim Burton            19 -67.291906  1075.738123  248.035751  195.227090
# Barry Levinson        18 -87.389990  1319.301740  171.782552   36.688846
# Oliver Stone          17 -82.227427  2209.093867  241.382763   47.892832
# Spike Lee             17 -82.710777  3978.572571  337.510765   45.969424
# ...

# %%
##most profitable directors
df_2=df.groupby('director')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='mean',ascending=False)
df_2=df_2[df_2['count']>=12]
df_2.head(20)
# Out:
#                     count        min           max         mean      median
# director
# Robert Rodriguez       13 -27.568730  29056.000000  2390.731374  215.061468
# Steven Spielberg       27 -36.460869   7451.529086   750.644852  323.528385
# M. Night Shyamalan     12 -95.297083   2993.937967   746.271435  284.126891
# Chris Columbus         13 -57.619869   2548.248194   592.666085  219.421586
# Richard Linklater      14 -61.288844   5239.600000   586.325356  121.478330
# Ivan Reitman           14 -66.354852   1344.095920   411.747097  134.181842
# Robert Zemeckis        17 -66.508997   1910.035589   406.389591  191.420351
# Spike Lee              17 -82.710777   3978.572571   337.510765   45.969424
# Garry Marshall         15 -72.633720   3210.044771   329.255786   95.130680
# Wes Craven             15 -44.679974   1317.063167   327.891475  231.093980
# Steven Soderbergh      23 -95.768000   2296.285157   297.251229   71.940200
# ...

# %%
d4 = df.groupby('director')['profit_percent'].agg(['count','median']).sort_values(by='median',ascending=False)
d4 = d4[d4['count']>=12]
d4 = d4.head(8)
d4 = d4.reset_index()
df_melted_4 = d4.melt(id_vars='director', value_vars=['count','median'], var_name='Statistic', value_name='Value')
plt.figure(figsize=(12, 8))
sns.barplot(x='Value', y='director', hue='Statistic', data=df_melted_4, palette='viridis')
plt.title('count and median profit percent by director')
plt.xlabel('Value')
plt.ylabel('director')
plt.legend(title='Statistic')
plt.show()

# %%
##actors who were the most active
df.groupby('star')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='count',ascending=False).head(20)
# Out:
#                        count        min          max        mean      median
# star
# Nicolas Cage              40 -74.079950  4855.313143  209.308715   49.256147
# Tom Hanks                 38 -69.434977  1214.788620  363.337245  299.566332
# Robert De Niro            38 -99.390658   455.899063   62.625196    3.100725
# Tom Cruise                34 -82.197986  2281.921187  348.278499  226.059522
# Bruce Willis              34 -98.514350  1582.015730  153.391121   67.464194
# Denzel Washington         33 -79.655872   421.846371  105.496361   86.940688
# Sylvester Stallone        32 -87.941122   901.579053  179.571287  112.752083
# Johnny Depp               31 -99.407647   373.857665  111.436707   88.255996
# Adam Sandler              28 -31.420829   708.659330  207.513567  167.387784
# Eddie Murphy              27 -92.896027  2159.717700  235.493952  103.907497
# Kevin Costner             27 -98.690486  1828.222036  241.488283   87.593261
# ...

# %%
##most profitable actors
df_1=df.groupby('star')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='mean',ascending=False)
df_1=df_1[df_1['count']>=20]
df_1.head(20)
# Out:
#                        count        min          max        mean      median
# star
# Tom Hanks                 38 -69.434977  1214.788620  363.337245  299.566332
# Ben Affleck               21 -86.544057  4708.508800  355.824645  119.308996
# Tom Cruise                34 -82.197986  2281.921187  348.278499  226.059522
# Jim Carrey                22 -48.169899  1428.623509  344.386023  229.787179
# Sandra Bullock            20 -69.544079  1466.817111  322.992556  202.608892
# Robin Williams            24 -96.201585  2159.334350  313.246946   83.946342
# Harrison Ford             26 -80.649826  2066.255394  298.055829   72.447849
# John Travolta             25 -85.995361  3859.997507  297.108012    1.624031
# Leonardo DiCaprio         20 -95.748263  1000.823632  283.553219  230.326290
# Richard Gere              22 -76.767732  3210.044771  276.775189   56.204243
# Arnold Schwarzenegger     26 -61.165279  1344.095920  268.453833  114.188179
# ...

# %%
d5 = df.groupby('star')['profit_percent'].agg(['count','median']).sort_values(by='median',ascending=False)
d5 = d5[d5['count']>=20]
d5 = d5.head(10)
d5 = d5.reset_index()
df_melted_5 = d5.melt(id_vars='star', value_vars=['count','median'], var_name='Statistic', value_name='Value')
plt.figure(figsize=(12, 8))
sns.barplot(x='Value', y='star', hue='Statistic', data=df_melted_5, palette='viridis')
plt.title('count and median profit percent by star')
plt.xlabel('Value')
plt.ylabel('star')
plt.legend(title='Statistic')
plt.show()

# %%
##genre based performance
genre_1='Horror'
df_3=df[df['genre']==genre_1]
df_3.groupby('writer')['profit_percent'].agg(['count','min','max','mean','median']).sort_values(by='count',ascending=False).head(10)
# Out:
#                   count         min          max         mean       median
# writer
# Stephen King          9  -29.258933  1721.123625   318.092068   116.678856
# Leigh Whannell        7   11.910235  8559.305750  3492.735030  3138.386360
# Rob Zombie            6  -43.305400   436.406320   149.655004   151.615926
# Wes Craven            5  -13.996748  1317.063167   420.176416   279.768454
# Kevin Williamson      4  143.078550  1136.047593   550.473063   461.383055
# John Carpenter        4  132.845080  2044.878200   867.956433   647.051227
# Gary Dauberman        4  670.841970  3862.758185  2009.659498  1752.518918
# Stephen Susco         3  253.555875  1772.811150  1176.288575  1502.498700
# Patrick Melton        3   32.396080   520.310491   207.760385    70.574583
# Glen Morgan           3  139.009456   390.783887   301.784810   375.561088
